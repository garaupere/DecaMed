# %%
import pandas as pd
castdf = pd.read_csv('corpora/castellano.csv', sep=';', encoding='utf-8')
catdf = pd.read_csv('corpora/catalán.csv', sep=';', encoding='utf-8')

print('Castellano', len(castdf))
print('Catalán', len(catdf))
# Out:
# Castellano 71136
# Catalán 17678
